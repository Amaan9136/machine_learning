# %% [markdown]
# <h2>Hierarchical Clustering</h2>
# <h3>Groups the data points depending on required clusters(groups) by using euclidean distance & Dendrogram between each clusters</h3>
# <h3>2 Types: Agglomerative(Small to Big) & Divisive(Big to Small)</h3>
# <h3>Here consider each data point and single cluster then make pairs depending on shortest path calculated by euclidean distance</h3>
# <img src="../../images/hierarchical-clustering.png" width="450px">

# %% [markdown]
# <h2>Dendrogram</h2>
# <h3>Used to find the best/optimal cluster value for the given data set</h3>
# <h3>The height of each dendrograms's box depends on euclidean distance of individual points</h3>
# <img src="../../images/dendrogram-1.png" width="450px">
# <img src="../../images/dendrogram-2.png" width="450px">

# %% [markdown]
# # Hierarchical Clustering

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('../../datasets/Mall_Customers.csv')
X = dataset.iloc[:,3:5].values

# HERE WHEN WE ARE DOING CLUSTERING WE ONLY NEED X's VALUES SINCE WE ONLY WANT TO GROUP

# print 5 values for above X array
print(X[0:5])
# Out:
# [[15 39]
#  [15 81]
#  [16  6]
#  [16 77]
#  [17 40]]

# %% [markdown]
# ## Using the Dendrogram to find the optimal number of clusters

# %%
import scipy.cluster.hierarchy as sch

# create dendrogram
sch.dendrogram(sch.linkage(X, method='ward'))

plt.title('Dendrogram Graph')
plt.xlabel('Customers Data')
plt.ylabel('Euclidean distance') 
plt.show()

# %% [markdown]
# ## Training the Hierarchical Clustering on the dataset for 5th Cluster Value

# %%
# the value 5 is obtained by considering the hightest value of euclidean distance by drawing a vertical line (----) which passes though its center
from sklearn.cluster import AgglomerativeClustering 

model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
y_pred = model.fit_predict(X)
# Out:
# c:\Users\Amaan M k\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %% [markdown]
# ## Visualising data before clustering

# %%
# create new data variable
data = dataset.iloc[:,3:5].values

# plot all data
plt.scatter(data[:,0],data[:,1], s=50, c='grey')

# %% [markdown]
# ## Visualising the clusters

# %%
# plot 5 clusters (0 to 4)
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1],s=50, c='red', label='Cluster 0')
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1],s=50, c='green', label='Cluster 1')
plt.scatter(X[y_pred == 2, 0], X[y_pred == 2, 1],s=50, c='cyan', label='Cluster 2')
plt.scatter(X[y_pred == 3, 0], X[y_pred == 3, 1],s=50, c='blue', label='Cluster 3')
plt.scatter(X[y_pred == 4, 0], X[y_pred == 4, 1],s=50, c='magenta', label='Cluster 4')

plt.legend()
