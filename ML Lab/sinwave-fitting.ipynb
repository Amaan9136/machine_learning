# %%
import numpy as np
import matplotlib.pyplot as plt

curve = 1.
x = (np.linspace(0,np.pi*2,100)) * curve
y = np.sin(x)+0.3*np.random.randn(100)
plt.plot(x,y,"r.")

y_pred = np.sin(x)
plt.plot(x,y_pred,"b-")
