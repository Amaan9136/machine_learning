# %%
average_pulse_max=max(80,85,90,95,100,105,110,115,120,125)
print(average_pulse_max)
# Out:
# 125

# %%
average_pulse_min=min(80,85,90,95,100,105,110,115,120,125)
print(average_pulse_min)
# Out:
# 80

# %%
import numpy as np
calorie_burnage=[240,250,260,270,280,290,300,310,320,330]
average_calorie_burnage=np.mean(calorie_burnage)
print(average_calorie_burnage)
# Out:
# 285.0

# %%
import pandas as pd
health_data=pd.read_csv(r"C:\Users\fg\Desktop\health_data.csv",header=0,sep=",")
print(health_data)
# Out:
#    Duration  Average_pulse  Max_pulse  Calorie_Burnage  Hours_Work  \
# 0        30             80        120              240          10
# 1        30             85        120              250          10
# 2        45             90        130              260           8
# 3        45             95        130              270           8
# 4        45            100        140              280           0
# 5        60            105        140              290           7
# 6        60            110        145              300           7
# 7        60            115        145              310           8
# 8        75            120        150              320           0
# 9        75            125        150              330           8
#
#    Hours_sleep
# 0            7
# 1            7
# 2            7
# 3            7
# 4            7
# 5            8
# 6            8
# 7            8
# 8            8
# 9            8

# %%
max(health_data.Max_pulse)
# Out:
# 150

# %%
min(health_data.Max_pulse)
# Out:
# 120

# %%
import numpy as np
np.mean(health_data.Calorie_Burnage)
# Out:
# 285.0

# %%
health_data.head()
# Out:
#    Duration  Average_pulse  Max_pulse  Calorie_Burnage  Hours_Work  \
# 0        30             80        120              240          10
# 1        30             85        120              250          10
# 2        45             90        130              260           8
# 3        45             95        130              270           8
# 4        45            100        140              280           0
#
#    Hours_sleep
# 0            7
# 1            7
# 2            7
# 3            7
# 4            7

# %%
health_data.tail()
# Out:
#    Duration  Average_pulse  Max_pulse  Calorie_Burnage  Hours_Work  \
# 5        60            105        140              290           7
# 6        60            110        145              300           7
# 7        60            115        145              310           8
# 8        75            120        150              320           0
# 9        75            125        150              330           8
#
#    Hours_sleep
# 5            8
# 6            8
# 7            8
# 8            8
# 9            8

# %%
health_data.plot()
# Out:
# <Axes: >

# %%
import matplotlib
matplotlib.use("Agg")
import pandas as pd
import matplotlib.pyplot as plt
health_data=pd.read_csv(r"C:\Users\fg\Desktop\health_data.csv",header=0,sep=",")
health_data.plot(x='Average_pulse',y='Calorie_Burnage',kind='line')
plt.ylim(ymin=60)
plt.xlim(xmin=60)
plt.savefig(r"C:\Users\fg\Desktop\health_data.png")
plt.close()

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

data = {'C': 20, 'C++': 15, 'Java': 30, 'Python': 35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(10, 5))
plt.bar(courses, values, color='green', width=0.4)
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

cars = ['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]

fig = plt.figure(figsize=(10, 7))
plt.pie(data, labels=cars)
plt.title("Car Brands Distribution")
plt.show()
