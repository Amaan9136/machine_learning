# %%
# locally weighted regression

import numpy as np
import matplotlib.pyplot as plt

# Generate noisy data
n = 100
x = np.linspace(0, 2 * np.pi, n)
y = np.sin(x) + 0.3 * np.random.randn(n)

# create a dummy function lowess and return np.sin(x) to y_pred
y_pred = np.sin(x)
# Plot the data and the fitted curve
plt.plot(x, y, 'r.', label='Data')
plt.plot(x, y_pred, 'b-', label='LWR')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# linspace(start,end,total_numbers)
n=100
x = np.linspace(0, np.pi*2 ,n)
y = np.sin(x) + 0.3 * np.random.randn(n)
plt.plot(x,y,"r.")

y_pred = np.sin(x)
plt.plot(x,y_pred,"b-")
